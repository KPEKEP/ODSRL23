# %%
# !pip install matplotlib
# Out:
# ...
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB 660.6 kB/s eta 0:00:12
#      -                                        0.3/7.6 MB 3.8 MB/s eta 0:00:02
#      ----                                     0.9/7.6 MB 6.9 MB/s eta 0:00:01
#      -------                                  1.5/7.6 MB 8.4 MB/s eta 0:00:01
#      ----------                               2.1/7.6 MB 9.4 MB/s eta 0:00:01
#      -------------                            2.6/7.6 MB 9.7 MB/s eta 0:00:01
#      ----------------                         3.2/7.6 MB 10.0 MB/s eta 0:00:01
#      -------------------                      3.7/7.6 MB 10.3 MB/s eta 0:00:01
#      ----------------------                   4.2/7.6 MB 10.3 MB/s eta 0:00:01
#      -------------------------                4.8/7.6 MB 10.6 MB/s eta 0:00:01
#      ---------------------------              5.3/7.6 MB 10.6 MB/s eta 0:00:01
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

class ExponentialInterpolator:
    def __init__(self, A, B):
        """Initialize the interpolator with start value A and end value B."""
        self.A = A
        self.B = B

    def __call__(self, t):
        """Interpolate between A and B using parameter t."""
        if t < 0 or t > 1:
            raise ValueError("Interpolation parameter t should be in the range [0, 1].")
        return self.A * (self.B / self.A) ** (t**(np.cos(np.pi/2 * t**0.2)))

# Create the interpolator
interpolator = ExponentialInterpolator(1, 10)

# Generate values for plotting
t_values = np.linspace(0, 1, 100)
interpolated_values = [interpolator(t) for t in t_values]

# Plot
plt.plot(t_values, interpolated_values, label="Fast Cosine Interpolation")
plt.xlabel("t")
plt.ylabel("Value")
plt.title("Fast Cosine Interpolation from 1 to 10")
plt.legend()
plt.grid(True)
plt.show()
